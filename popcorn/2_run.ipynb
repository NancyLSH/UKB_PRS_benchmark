# %%
# python -m Popcorn fit -v 1 --use_mle --cfile Popcorn/test/EUR_EAS_test_ge.cscore --gen_effect --sfile1 Popcorn/test/EUR_test.txt --sfile2 Popcorn/test/EAS_test.txt Popcorn/test/EAS_EUR_test_ge_result.txt

# test
# popcorn fit -v 1 --cfile /data1/jiapl_group/lishuhua/software/general/Popcorn-master/score/EUR_EAS_all_gen_eff.cscore --gen_effect --sfile1 /data1/jiapl_group/lishuhua/project/PRS_benchmark/real_data/UKB/merged_gwas/White_British/munged/p48_int.merged.sumstats.gz --sfile2 /data1/jiapl_group/lishuhua/project/PRS_benchmark/real_data/CAS/gwas/munged/waist_int.waist_int.sumstats.gz /data1/jiapl_group/lishuhua/project/PRS_benchmark/software/popcorn/res/waist.txt

# %%
import pandas as pd
import numpy as np
import sys
import os

eas_sumstats_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/real_data/CAS/gwas/munged/"
eur_sumstats_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/real_data/UKB/merged_gwas/White_British/munged/"
output_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/software/popcorn/res/"
score_file_path = "/data1/jiapl_group/lishuhua/software/general/Popcorn-master/score/EUR_EAS_all_gen_eff.cscore"

trait_dict = {
        'p48': 'waist',
        'p50': 'height',
        'p102': 'pulse',
        'p4079': 'dbp',
        'p4080': 'sbp',
        'p20116': 'smoke',
        'p20117': 'drink',
        'p21001': 'bmi',
        'p30000': 'wbc',
        'p30010': 'rbc',
        'p30020':'hb',
        'p30080': 'plt',
        'p30120': 'lymph',
        'p30130': 'mono',
        'p30140': 'neut',
        'p30150': 'eos',
        'p30620': 'alt',
        'p30650': 'ast',
        'p30670': 'bun',
        'p30690': 'cholesterol',
        'p30700': 'creatinine',
        'p30730': 'ggt',
        'p30740': 'glucose',
        'p30760': 'hdl',
        'p30780': 'ldl',
        'p30870': 'triglycerides',
        'p30880': 'ua'
    }

for trait, name in trait_dict.items():
    eas_sumstats_path = f"{eas_sumstats_dir}/{name}_int.{name}_int.sumstats.gz"
    if name in ['smoke', 'drink']:
        eas_sumstats_path = f"{eas_sumstats_dir}/{name}_raw.{name}_raw.sumstats.gz"
    eur_sumstats_path = f"{eur_sumstats_dir}/{trait}_int.merged.sumstats.gz"
    output_path = f"{output_dir}/{name}.txt"
    cmd = f"popcorn fit -v 1 --cfile {score_file_path} --gen_effect --sfile1 {eur_sumstats_path} --sfile2 {eas_sumstats_path} {output_path}"
    if os.path.exists(eur_sumstats_path) and os.path.exists(eas_sumstats_path):
        # print(cmd)
        print(f"Running Popcorn for trait: {name}")
        os.system(cmd)

# %%
import pandas as pd
import numpy as np
import sys
import os

eas_sumstats_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/real_data/UKB/merged_gwas/Chinese/munged/"
eur_sumstats_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/real_data/UKB/merged_gwas/White_British/munged/"
output_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/software/popcorn/res_for_ukb/"
score_file_path = "/data1/jiapl_group/lishuhua/software/general/Popcorn-master/score/EUR_EAS_all_gen_eff.cscore"

trait_dict = {
        'p48': 'waist',
        'p50': 'height',
        'p102': 'pulse',
        'p4079': 'dbp',
        'p4080': 'sbp',
        'p20116': 'smoke',
        'p20117': 'drink',
        'p21001': 'bmi',
        'p30000': 'wbc',
        'p30010': 'rbc',
        'p30020':'hb',
        'p30080': 'plt',
        'p30120': 'lymph',
        'p30130': 'mono',
        'p30140': 'neut',
        'p30150': 'eos',
        'p30620': 'alt',
        'p30650': 'ast',
        'p30670': 'bun',
        'p30690': 'cholesterol',
        'p30700': 'creatinine',
        'p30730': 'ggt',
        'p30740': 'glucose',
        'p30760': 'hdl',
        'p30780': 'ldl',
        'p30870': 'triglycerides',
        'p30880': 'ua'
    }

for trait, name in trait_dict.items():
    eas_sumstats_path = f"{eas_sumstats_dir}/{trait}_int.merged.sumstats.gz"
    eur_sumstats_path = f"{eur_sumstats_dir}/{trait}_int.merged.sumstats.gz"
    output_path = f"{output_dir}/{name}.txt"
    if os.path.exists(output_path):
        print(f"Output file already exists for trait: {name}, skipping...")
        continue
    cmd = f"popcorn fit -v 1 --cfile {score_file_path} --gen_effect --sfile1 {eur_sumstats_path} --sfile2 {eas_sumstats_path} {output_path}"
    if os.path.exists(eur_sumstats_path) and os.path.exists(eas_sumstats_path):
        # print(cmd)
        print(f"Running Popcorn for trait: {name}")
        os.system(cmd)

# %%
import pandas as pd
import numpy as np
import sys
import os

eas_sumstats_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/software/popcorn/gwas/EAS/"
eur_sumstats_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/software/popcorn/gwas/EUR/"
output_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/software/popcorn/res/"
score_file_path = "/data1/jiapl_group/lishuhua/software/general/Popcorn-master/score/EUR_EAS_all_gen_eff.cscore"

trait_dict = {
        'p48': 'waist',
        'p50': 'height',
        'p102': 'pulse',
        'p4079': 'dbp',
        'p4080': 'sbp',
        'p20116': 'smoke',
        'p20117': 'drink',
        'p21001': 'bmi',
        'p30000': 'wbc',
        'p30010': 'rbc',
        'p30020':'hb',
        'p30080': 'plt',
        'p30120': 'lymph',
        'p30130': 'mono',
        'p30140': 'neut',
        'p30150': 'eos',
        'p30620': 'alt',
        'p30650': 'ast',
        'p30670': 'bun',
        'p30690': 'cholesterol',
        'p30700': 'creatinine',
        'p30730': 'ggt',
        'p30740': 'glucose',
        'p30760': 'hdl',
        'p30780': 'ldl',
        'p30870': 'triglycerides',
        'p30880': 'ua'
    }

for trait, name in trait_dict.items():
    eas_sumstats_path = f"{eas_sumstats_dir}/{name}.txt"
    eur_sumstats_path = f"{eur_sumstats_dir}/{name}.txt"
    output_path = f"{output_dir}/{name}.txt"
    cmd = f"popcorn fit -v 1 --cfile {score_file_path} --gen_effect --sfile1 {eur_sumstats_path} --sfile2 {eas_sumstats_path} {output_path}"
    if os.path.exists(output_path):
        print(f"Output for trait {name} already exists. Skipping...")
        continue
    if os.path.exists(eur_sumstats_path) and os.path.exists(eas_sumstats_path):
        # print(cmd)
        print(f"Running Popcorn for trait: {name}")
        os.system(cmd)

# %%
import pandas as pd
import numpy as np
import sys
import os

eas_sumstats_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/software/popcorn/gwas/EAS/"
eur_sumstats_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/software/popcorn/gwas/EUR/"
output_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/software/popcorn/res/"
score_file_path = "/data1/jiapl_group/lishuhua/software/general/Popcorn-master/score/EUR_EAS_all_gen_eff.cscore"

# trait_dict = {
#         'p48': 'waist',
#         'p50': 'height',
#         'p102': 'pulse',
#         'p4079': 'dbp',
#         'p4080': 'sbp',
#         'p20116': 'smoke',
#         'p20117': 'drink',
#         'p21001': 'bmi',
#         'p30000': 'wbc',
#         'p30010': 'rbc',
#         'p30020':'hb',
#         'p30080': 'plt',
#         'p30120': 'lymph',
#         'p30130': 'mono',
#         'p30140': 'neut',
#         'p30150': 'eos',
#         'p30620': 'alt',
#         'p30650': 'ast',
#         'p30670': 'bun',
#         'p30690': 'cholesterol',
#         'p30700': 'creatinine',
#         'p30730': 'ggt',
#         'p30740': 'glucose',
#         'p30760': 'hdl',
#         'p30780': 'ldl',
#         'p30870': 'triglycerides',
#         'p30880': 'ua'
#     }
trait_dict = {
        'p48': 'waist'
    }

for trait, name in trait_dict.items():
    eas_sumstats_path = f"{eas_sumstats_dir}/{name}.txt"
    eur_sumstats_path = f"{eur_sumstats_dir}/{name}.txt"
    output_path = f"{output_dir}/{name}.txt"
    cmd = f"popcorn fit -v 1 --cfile {score_file_path} --gen_effect --sfile1 {eur_sumstats_path} --sfile2 {eas_sumstats_path} {output_path}"
    if os.path.exists(output_path):
        print(f"Output for trait {name} already exists. Skipping...")
        continue
    if os.path.exists(eur_sumstats_path) and os.path.exists(eas_sumstats_path):
        # print(cmd)
        print(f"Running Popcorn for trait: {name}")
        os.system(cmd)
