# %%
import pandas as pd
import numpy as np
import os

def run_single_trait(ma_path, output_path):
    """
    Run SBayesR for a single trait.
    """
    cmd = f"/data1/jiapl_group/lishuhua/software/PRS/GCTB/gctb_2.5.2_Linux/gctb --sbayes R --ldm {ldm_path} --pi 0.95,0.02,0.02,0.01 --gamma 0.0,0.001,0.01,0.05 --gwas-summary {ma_path} --out-freq 10 --out {output_path}"
    # run the command in one thread and print all output into a log file
    print(f"Running command: {cmd}")
    # Redirect output to log file
    os.system(f"{cmd} > {output_path}.log 2>&1")

if __name__ == "__main__":
    ldm_path = "/data1/jiapl_group/lishuhua/software/PRS/GCTB/LD_matrix/ukbEURu_imp_v3_HM3_n50k.chisq10.ldm.sparse"
    ma_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/software/polypred/train/EUR/4_sbayesr/"
    gctb_exec = "/data1/jiapl_group/lishuhua/software/PRS/GCTB/gctb_2.5.1_Linuxx/gctb"

    # TRAIT_LIST = ['hb', 'plt', 'lymph', 'mono', 'neut', 'eos', 'bun', 'cholesterol', 'creatinine', 'glucose', 'ggt', 'hdl', 'ldl', 'triglycerides', 'ua']
    # TRAIT_LIST = ['waist', 'alt', 'ast', 'bmi', 'height', 'pulse', 'dbp', 'sbp', 'smoke', 'drink', 'wbc', 'rbc']
    TRAIT_LIST = ['height', 'sbp', 'smoke', 'drink', 'wbc', 'rbc']

    for trait in TRAIT_LIST:
        ma_path = os.path.join(ma_dir, f"{trait}.ma")
        output_path = os.path.join(ma_dir, f"{trait}.sbayesr")
        print(f"Processing trait: {trait}")
        run_single_trait(ma_path, output_path)

# %%
import pandas as pd
import numpy as np
import os

def run_single_trait(ma_path, output_path):
    """
    Run SBayesR for a single trait.
    """
    cmd = f"/data1/jiapl_group/lishuhua/software/PRS/GCTB/gctb_2.5.2_Linux/gctb --sbayes R --ldm {ldm_path} --pi 0.95,0.02,0.02,0.01 --gamma 0.0,0.001,0.01,0.01 --gwas-summary {ma_path} --out-freq 10 --out {output_path}"
    # run the command in one thread and print all output into a log file
    print(f"Running command: {cmd}")
    # Redirect output to log file
    os.system(f"{cmd} > {output_path}.log 2>&1")

if __name__ == "__main__":
    ldm_path = "/data1/jiapl_group/lishuhua/software/PRS/GCTB/LD_matrix/ukbEURu_imp_v3_HM3_n50k.chisq10.ldm.sparse"
    ma_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/software/polypred/train/EUR/4_sbayesr/"
    gctb_exec = "/data1/jiapl_group/lishuhua/software/PRS/GCTB/gctb_2.5.1_Linuxx/gctb"

    # TRAIT_LIST = ['height', 'pulse', 'dbp', 'sbp', 'smoke', 'drink', 'wbc', 'rbc']
    # TRAIT_LIST = ['waist', 'alt', 'ast', 'bmi', 'hb','plt', 'lymph', 'mono', 'neut', 'eos', 'bun', 'creatinine', 'glucose', 'cholesterol', 'ggt', 'hdl', 'ldl', 'triglycerides', 'ua']
    TRAIT_LIST = ['ua']

    for trait in TRAIT_LIST:
        ma_path = os.path.join(ma_dir, f"{trait}.ma")
        output_path = os.path.join(ma_dir, f"{trait}.sbayesr")
        print(f"Processing trait: {trait}")
        run_single_trait(ma_path, output_path)

# %%
import pandas as pd
import numpy as np
import os

def run_single_trait(ma_path, output_path):
    """
    Run SBayesR for a single trait.
    """
    cmd = f"/data1/jiapl_group/lishuhua/software/PRS/GCTB/gctb_2.5.2_Linux/gctb --sbayes R --ldm {ldm_path} --pi 0.95,0.02,0.02,0.01 --gamma 0.0,0.001,0.01,0.005 --gwas-summary {ma_path} --out-freq 10 --out {output_path}"
    # run the command in one thread and print all output into a log file
    print(f"Running command: {cmd}")
    # Redirect output to log file
    os.system(f"{cmd} > {output_path}.log 2>&1")

if __name__ == "__main__":
    ldm_path = "/data1/jiapl_group/lishuhua/software/PRS/GCTB/LD_matrix/ukbEURu_imp_v3_HM3_n50k.chisq10.ldm.sparse"
    ma_dir = "/data1/jiapl_group/lishuhua/project/PRS_benchmark/software/polypred/train/EUR/4_sbayesr/"
    gctb_exec = "/data1/jiapl_group/lishuhua/software/PRS/GCTB/gctb_2.5.1_Linuxx/gctb"

    # TRAIT_LIST = ['height', 'pulse', 'dbp', 'sbp', 'smoke', 'drink', 'wbc', 'rbc']
    # TRAIT_LIST = ['waist', 'alt', 'ast', 'bmi', 'hb','plt', 'lymph', 'mono', 'neut', 'eos', 'bun', 'creatinine', 'glucose', 'cholesterol', 'ggt', 'hdl', 'ldl', 'triglycerides', 'ua']
    TRAIT_LIST = ['height']

    for trait in TRAIT_LIST:
        ma_path = os.path.join(ma_dir, f"{trait}.ma")
        output_path = os.path.join(ma_dir, f"{trait}.sbayesr")
        print(f"Processing trait: {trait}")
        run_single_trait(ma_path, output_path)
